# %% [markdown]
# # Part1

# %%
import pandas as pd

df = pd.read_csv("/Users/marcobispo/Documents/pratica_python/pandas/data/survey_results_public.csv")
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
print(f'lines: {df.shape[0]}, columns: {df.shape[1]}')
# Out:
# lines: 88883, columns: 85

# %%
type(df.info())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 85)
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
schema_df = pd.read_csv('/Users/marcobispo/Documents/pratica_python/pandas/data/survey_results_schema.csv')
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 20)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %% [markdown]
# # Part 2

# %%
person = {
    "nome":["marco"],
    "sobre nome":["bispo"],
    "email":["marcobispo97@gmail.com"]
}
df1 = pd.DataFrame(person)
df1
# Out:
#     nome sobre nome                   email
# 0  marco      bispo  marcobispo97@gmail.com

# %%
person = {
    "nome":["marco"],
    "sobre nome":["bispo"],
    "email":["marcobispo97@gmail.com"]
}
df2 = pd.DataFrame(person)
df2
# Out:
#     nome sobre nome                   email
# 0  marco      bispo  marcobispo97@gmail.com

# %%
pessoas = {
    "nome":["marco","ana","bianca","joao"],
    "sobre nome":["bispo","laura","amanda","victor"],
    "email":["marcobispo97@gmail.com","analaura_38@gmail.com","amanda65@yahoo.com","jv_78@gmail.com"],
    "idade":[23,25,31,33]
}
df2 = pd.DataFrame(pessoas)
print(pessoas["nome"])
display(df2['nome'])
display(df2[['nome']])
display(df2[['nome','email']])
df2
# Out:
# ['marco', 'ana', 'bianca', 'joao']
# 0     marco
# 1       ana
# 2    bianca
# 3      joao
# Name: nome, dtype: object
#      nome
# 0   marco
# 1     ana
# 2  bianca
# 3    joao
#      nome                   email
# 0   marco  marcobispo97@gmail.com
# 1     ana   analaura_38@gmail.com
# 2  bianca      amanda65@yahoo.com
# 3    joao         jv_78@gmail.com
#      nome sobre nome                   email  idade
# 0   marco      bispo  marcobispo97@gmail.com     23
# 1     ana      laura   analaura_38@gmail.com     25
# 2  bianca     amanda      amanda65@yahoo.com     31
# 3    joao     victor         jv_78@gmail.com     33

# %%
display(df2.loc[3])
display(df2.iloc[3])
display(df2.loc[[3]])
display(df2.iloc[[3]])
display(df2.loc[0:2])
display(df2.iloc[0:2,0:2])
display(df2.loc[[0,1],["nome","sobre nome"]])
display(df2.loc[df2["idade"]>23])
# Out:
# nome                     joao
# sobre nome             victor
# email         jv_78@gmail.com
# idade                      33
# Name: 3, dtype: object
# nome                     joao
# sobre nome             victor
# email         jv_78@gmail.com
# idade                      33
# Name: 3, dtype: object
#    nome sobre nome            email  idade
# 3  joao     victor  jv_78@gmail.com     33
#    nome sobre nome            email  idade
# 3  joao     victor  jv_78@gmail.com     33
#      nome sobre nome                   email  idade
# 0   marco      bispo  marcobispo97@gmail.com     23
# 1     ana      laura   analaura_38@gmail.com     25
# 2  bianca     amanda      amanda65@yahoo.com     31
#     nome sobre nome
# 0  marco      bispo
# 1    ana      laura
#     nome sobre nome
# 0  marco      bispo
# 1    ana      laura
#      nome sobre nome                  email  idade
# 1     ana      laura  analaura_38@gmail.com     25
# 2  bianca     amanda     amanda65@yahoo.com     31
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.loc[0:3,'Hobbyist':'OrgSize']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
# 3       No                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %% [markdown]
# # Part3

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
pessoas = {
    "nome":["marco","ana","bianca","joao"],
    "sobre nome":["bispo","laura","amanda","victor"],
    "email":["marcobispo97@gmail.com","analaura_38@gmail.com","amanda65@yahoo.com","jv_78@gmail.com"],
    "idade":[23,25,31,33]
}
df2 = pd.DataFrame(pessoas)
print(pessoas["nome"])
display(df2['nome'])
display(df2[['nome']])
display(df2[['nome','email']])
df2

df2.set_index('email', inplace=True)
df2
# Out:
# ['marco', 'ana', 'bianca', 'joao']
# 0     marco
# 1       ana
# 2    bianca
# 3      joao
# Name: nome, dtype: object
#      nome
# 0   marco
# 1     ana
# 2  bianca
# 3    joao
#      nome                   email
# 0   marco  marcobispo97@gmail.com
# 1     ana   analaura_38@gmail.com
# 2  bianca      amanda65@yahoo.com
# 3    joao         jv_78@gmail.com
#                           nome sobre nome  idade
# email
# marcobispo97@gmail.com   marco      bispo     23
# analaura_38@gmail.com      ana      laura     25
# amanda65@yahoo.com      bianca     amanda     31
# jv_78@gmail.com           joao     victor     33

# %%
df2.index
# Out:
# Index(['marcobispo97@gmail.com', 'analaura_38@gmail.com', 'amanda65@yahoo.com',
#        'jv_78@gmail.com'],
#       dtype='object', name='email')

# %%
df2.loc['marcobispo97@gmail.com']
# Out:
# nome          marco
# sobre nome    bispo
# idade            23
# Name: marcobispo97@gmail.com, dtype: object

# %%
df2.loc['marcobispo97@gmail.com','idade']
# Out:
# 23

# %%
df2.iloc[0]
# Out:
# nome          marco
# sobre nome    bispo
# idade            23
# Name: marcobispo97@gmail.com, dtype: object

# %%
df2.reset_index(inplace=True)
df2
# Out:
#                     email    nome sobre nome  idade
# 0  marcobispo97@gmail.com   marco      bispo     23
# 1   analaura_38@gmail.com     ana      laura     25
# 2      amanda65@yahoo.com  bianca     amanda     31
# 3         jv_78@gmail.com    joao     victor     33

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
import pandas as pd

df = pd.read_csv("/Users/marcobispo/Documents/pratica_python/pandas/data/survey_results_public.csv", index_col='Respondent')
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df2
# Out:
#                     email    nome sobre nome  idade
# 0  marcobispo97@gmail.com   marco      bispo     23
# 1   analaura_38@gmail.com     ana      laura     25
# 2      amanda65@yahoo.com  bianca     amanda     31
# 3         jv_78@gmail.com    joao     victor     33

# %%
schema_df = pd.read_csv('/Users/marcobispo/Documents/pratica_python/pandas/data/survey_results_schema.csv')
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema_df.set_index("Column", inplace=True)
schema_df
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
schema_df.sort_index(inplace=True)
schema_df
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]

# %% [markdown]
# # Part 4

# %%
pessoas = {
    "nome":["marco","ana","bianca","joao"],
    "sobre nome":["bispo","silva","silva","victor"],
    "email":["marcobispo97@gmail.com","analaura_38@gmail.com","amanda65@yahoo.com","jv_78@gmail.com"],
    "idade":[23,25,31,33]
}
df2 = pd.DataFrame(pessoas)
print(pessoas["nome"])
display(df2['nome'])
display(df2[['nome']])
display(df2[['nome','email']])
df2

df2.set_index('email', inplace=True)
df2
# Out:
# ['marco', 'ana', 'bianca', 'joao']
# 0     marco
# 1       ana
# 2    bianca
# 3      joao
# Name: nome, dtype: object
#      nome
# 0   marco
# 1     ana
# 2  bianca
# 3    joao
#      nome                   email
# 0   marco  marcobispo97@gmail.com
# 1     ana   analaura_38@gmail.com
# 2  bianca      amanda65@yahoo.com
# 3    joao         jv_78@gmail.com
#                           nome sobre nome  idade
# email
# marcobispo97@gmail.com   marco      bispo     23
# analaura_38@gmail.com      ana      silva     25
# amanda65@yahoo.com      bianca      silva     31
# jv_78@gmail.com           joao     victor     33

# %%
df2.reset_index(inplace=True)
filtro = df2['sobre nome'] == 'silva'
df2[filtro]
# Out:
#    index                  email    nome sobre nome  idade
# 1      1  analaura_38@gmail.com     ana      silva     25
# 2      2     amanda65@yahoo.com  bianca      silva     31

# %%
df2.loc[filtro, 'email']
# Out:
# 1    analaura_38@gmail.com
# 2       amanda65@yahoo.com
# Name: email, dtype: object

# %%
filtro = (df2['sobre nome'] == 'silva') & (df2['nome'] == 'ana')
display(df2[filtro])
display(df2[~filtro])
# Out:
#    index                  email nome sobre nome  idade
# 1      1  analaura_38@gmail.com  ana      silva     25
#    index                   email    nome sobre nome  idade
# 0      0  marcobispo97@gmail.com   marco      bispo     23
# 2      2      amanda65@yahoo.com  bianca      silva     31
# 3      3         jv_78@gmail.com    joao     victor     33

# %%
df
high_salary = (df['ConvertedComp']>70000)
df.loc[high_salary, ['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']

filt = df['Country'].isin(countries)

df[filt]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 4                              I am a developer by profession       No
# 6           I am not primarily a developer, but I write co...      Yes
# 8                                 I code primarily as a hobby      Yes
# 10                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 85642                                                     NaN       No
# 85961                                                     NaN      Yes
# 86012                                                     NaN      Yes
# 88282                                                     NaN      Yes
# 88377                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na = False)
df[filt]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
# ...                                            ...      ...
# 84539                                          NaN      Yes
# 85738                                          NaN      Yes
# 86566                                          NaN      Yes
# 87739                                          NaN      Yes
# 88212                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...
